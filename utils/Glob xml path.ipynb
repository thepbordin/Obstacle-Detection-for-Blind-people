# %%
import glob

# %%
path = glob.glob("Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC/annotation/*.xml")
path
# Out:
# ['Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC/annotation\\000bf0ddff4c7310_jpg.rf.fccbb53e7330edd7726dd48b75147235.xml',
#  'Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC/annotation\\000c052bb4b882c4_jpg.rf.62d023ca01124db5d34eaa87d9ff96bc.xml',
#  'Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC/annotation\\000c66e044e850f7_jpg.rf.0bfead3e65203a780558ab5eab44b430.xml',
#  'Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC/annotation\\000c9e454bbf6d0d_jpg.rf.1ffdea79c5549870d69a3e13393f06aa.xml',
#  'Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC/annotation\\000ceb7c62a21547_jpg.rf.07c4ae081e3914717713f09324f3b5a0.xml',
#  'Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC/annotation\\000cf08de329f81b_jpg.rf.a7794dc97e51b9446da66734ec816007.xml',
#  'Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC/annotation\\000d61ba9ffa87db_jpg.rf.ef141952f0e1c5c66965b7b787f31ba8.xml',
# ...

# %%
with open('path.txt', 'w') as f:
    for p in path:
        x = p.replace("Pybordin/Project/data/DoorDetect-Dataset-master/Pascal VOC", ".")
        f.write(x)
        f.write("\n")
