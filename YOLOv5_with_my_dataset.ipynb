# %% [markdown]
# # **📦Obstacle-Detection-for-Blind-people by YOLOv5🚀**
# **This notebook was modified from [YOLOv5 Tutorial.](https://github.com/ultralytics/yolov5)**
#
# [Obstacle-Detection-for-Blind-people - Github
# ](https://github.com/thepbordin/Obstacle-Detection-for-Blind-people)

# %% [markdown]
# # Install Requirements

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow
# !pip install gdown

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12269, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 12269 (delta 5), reused 8 (delta 1), pack-reused 12250
# Receiving objects: 100% (12269/12269), 12.04 MiB | 13.90 MiB/s, done.
# Resolving deltas: 100% (8491/8491), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 6.0 MB/s
#      |████████████████████████████████| 145 kB 5.2 MB/s
#      |████████████████████████████████| 178 kB 46.3 MB/s
#      |████████████████████████████████| 1.1 MB 59.6 MB/s
#      |████████████████████████████████| 67 kB 5.8 MB/s
#      |████████████████████████████████| 54 kB 3.1 MB/s
#      |████████████████████████████████| 138 kB 12.4 MB/s
#      |████████████████████████████████| 62 kB 1.6 MB/s
# ...

# %% [markdown]
# # Prepare our dataset.

# %%
# !gdown "https://drive.google.com/u/1/uc?id=1H-c_LQY5qA7YyksffRuPDr4SVzY_-Xp0&export=download"
# Out:
# Downloading...
# From: https://drive.google.com/u/1/uc?id=1H-c_LQY5qA7YyksffRuPDr4SVzY_-Xp0&export=download
# To: /content/yolov5/yolo dataset3.0.zip
# 100% 384M/384M [00:03<00:00, 120MB/s]

# %%
# !unzip "/content/yolov5/yolo dataset3.0.zip" -d "/content/data/"
# Out:
# Archive:  /content/yolov5/yolo dataset3.0.zip
#    creating: /content/data/test/
#    creating: /content/data/test/images/
#   inflating: /content/data/test/images/1003.png
#   inflating: /content/data/test/images/1014.png
#   inflating: /content/data/test/images/1015.png
#   inflating: /content/data/test/images/1020.png
#   inflating: /content/data/test/images/1021.png
#   inflating: /content/data/test/images/1023.png
#   inflating: /content/data/test/images/1026.png
#   inflating: /content/data/test/images/1027.png
#   inflating: /content/data/test/images/1028.png
#   inflating: /content/data/test/images/1029.png
#   inflating: /content/data/test/images/1032.png
#   inflating: /content/data/test/images/1034.png
#   inflating: /content/data/test/images/1040.png
#   inflating: /content/data/test/images/1043.png
#   inflating: /content/data/test/images/1045.png
#   inflating: /content/data/test/images/1047.png
#   inflating: /content/data/test/images/1048.png
# ...

# %% [markdown]
# # Let's Train👾
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** Our dataset locaiton is saved in the `dataset.location`
# - **weights:** specify a path to weights to start transfer learning from. Here we choose the generic COCO pretrained checkpoint.
# - **cache:** cache images for faster training

# %%
# !python train.py --img 416 --batch 16 --epochs 300 --data /content/data/data.yaml --weights yolov5x.pt --cache

# %% [markdown]
# # Evaluate Model on test set
# ## ***Dont forget**  to change dir to last weight you trained!!

# %%
# !python val.py --task test --weights yolov5/runs/train/exp/weights/best.pt --data yolov5/data.yaml

# %%
# !zip -r ~/fu_workspace/yolov5xDataset3AWSTest.zip yolov5/runs/val/exp

# %% [markdown]
# # ZIP File and save

# %%
# !zip -r "trained.zip" "/content/yolov5/runs/train/exp3"
